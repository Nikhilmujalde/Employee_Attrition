# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Employee-Attrition.csv')

# %%
df.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 729    35        No      Travel_Rarely        583  Research & Development
# 1250   29        No  Travel_Frequently        461  Research & Development
# 176    33        No      Travel_Rarely        134  Research & Development
# 969    48        No      Travel_Rarely        855  Research & Development
# 1240   39        No         Non-Travel        792  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 729                 25          4        Medical              1
# 1250                 1          3  Life Sciences              1
# 176                  2          3  Life Sciences              1
# 969                  4          3  Life Sciences              1
# 1240                 1          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# here we can get many info like the avg age of employee,the daily rate ,education and many more which will be important in training models

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
pd.set_option('display.max_columns',None)
# to see all the columns

# %%
df.sample(5)
# now we can see all the 35 col
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 703    38        No         Non-Travel        152                   Sales
# 47     37        No      Travel_Rarely        408  Research & Development
# 838    42       Yes  Travel_Frequently        481                   Sales
# 1206   26        No         Non-Travel        786  Research & Development
# 279    50        No      Travel_Rarely        797  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 703                 10          3  Technical Degree              1
# 47                  19          2     Life Sciences              1
# 838                 12          3     Life Sciences              1
# 1206                 7          3           Medical              1
# 279                  4          1     Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# so here we can see that there are no missing values
# but here we have some categorical col so we need to change them to numerical col

# %%
# checking for duplicates
print(df.duplicated().value_counts())
# Out:
# False    1470
# Name: count, dtype: int64

# %%
# so we have no duplicates
# also check for missing or null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# we don't have any null or missing values

# %%
# checking our output
plt.figure(figsize=(15,5))
plt.hist(df['Attrition'])
plt.xlabel('Attrition')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# here we can observe that only a small number of people around 200 have attrition to be true
# here we have imbalanced data set as we have only have a small number of yes in the attrition col so it will be difficult for
# us to predict what will be the cause of the people living

# %%
# now we will see attrition wrt to some other parameters which may have an impact

# %%
# Department wrt Attrition
plt.figure(figsize=(12,5))
# Count plot of Attrition vs Department
plt.figure(figsize=(15, 5))
sns.countplot(data=df, x='Department', hue='Attrition')

# Add labels and title
plt.xlabel('Department')
plt.ylabel('Count')
plt.title('Attrition by Department')
# Out:
# Text(0.5, 1.0, 'Attrition by Department')

# %%
df.groupby('Department')['Attrition'].describe()
# Out:
#                        count unique top freq
# Department
# Human Resources           63      2  No   51
# Research & Development   961      2  No  828
# Sales                    446      2  No  354

# %%
# Group by Department and Attrition and get the size of each group
attrition_counts = df.groupby(['Department', 'Attrition']).size().unstack(fill_value=0)
print(attrition_counts)
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# here we can observe that human resource and the sales both have almost 20% attrition rate so this can be importanat factor

# %%
# wrt to education field
plt.figure(figsize=(12,5))
sns.countplot(x='EducationField',hue='Attrition', data=df, palette='hot')
plt.title("Attrition w.r.t EducationField")
# if the names are bigger we can handle them this way
plt.xticks(rotation=45)
plt.show()

# %%
attrition_counts = df.groupby(['EducationField', 'Attrition']).size().unstack(fill_value=0)
print(attrition_counts)
# Out:
# Attrition          No  Yes
# EducationField
# Human Resources    20    7
# Life Sciences     517   89
# Marketing         124   35
# Medical           401   63
# Other              71   11
# Technical Degree  100   32

# %%
# let's see at which post most people are leaving the jobs
# JobRole
plt.figure(figsize=(12,5))
sns.countplot(x='JobRole',hue='Attrition', data=df, palette='hot')
plt.title("JobRole w.r.t Attrition")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %%
# most male of female employes Attriate
# Department wrt Attrition
plt.figure(figsize=(12,5))
sns.countplot(x='Gender',hue='Attrition', data=df, palette='hot')
plt.title("Gender w.r.t Attrition")
plt.legend(loc='best')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='DailyRate', data=df)
plt.title('DailyRate vs Attrition ')
plt.xlabel('Attrition')
plt.ylabel('DailyRate')
plt.show()

# %%
# here we can see that people who leaves have less dailyrate than the people who stays so this could be a very important factor

# %%
numerical_features = ['Age', 'DailyRate', 'DistanceFromHome', 'MonthlyIncome', 'YearsAtCompany', 
                      'Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'HourlyRate', 
                      'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 
                      'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 
                      'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 
                      'TotalWorkingYears']
num_features = len(numerical_features)
num_cols = 3
num_rows = (num_features + num_cols - 1) // num_cols  # Ceiling division

plt.figure(figsize=(20, 5 * num_rows))  # Adjust height based on number of rows
# plt.figure(figsize=(15, 10))
# Limit the number of features to plot (adjust as needed)
for i, feature in enumerate(numerical_features):
    plt.subplot(num_rows, num_cols, i+1)
    sns.boxplot(x='Attrition', y=feature, data=df, palette='coolwarm')
    plt.title(f'{feature} by Attrition')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_12712\3212896247.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df, palette='coolwarm')
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_12712\3212896247.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df, palette='coolwarm')
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_12712\3212896247.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df, palette='coolwarm')
# ...

# %%
# here we can see that many col have no or very less effect on the attrition so we don't need them in our model training
# education hourly rate, job environment, employee count,stock,performance rating ,relationship satisfaction

# %%
categorical_features = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']
plt.figure(figsize=(15, 20))
for i, feature in enumerate(categorical_features):
    plt.subplot(3, 2, i+1)
    sns.countplot(x=feature, hue='Attrition', data=df, palette='coolwarm')
    plt.title(f'{feature} by Attrition')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
edu_map = {1 :'Below College', 2: 'College', 3 :'Bachelor', 4 :'Master', 5: 'Doctor'}
plt.figure(figsize=(12,5))
sns.countplot(x=df['Education'].map(edu_map), hue='Attrition', data=df, palette='hot')
plt.title("Education W.R.T Attrition")
plt.show()

# %%
# Employees from Bachelor are more, then from Masters background. Attrition wrt to bachelor can be seem more because they have more and more 
# expectation from companies and it will be interesting to see the reason behind this in this dataset.

# %% [markdown]
# # Label Encoding

# %%
df['Attrition'] = df['Attrition'].replace({'No':0,'Yes':1})
df['OverTime'] = df['OverTime'].map({'No':0,'Yes':1})
df['Gender'] = df['Gender'].map({'Male':0,'Female':1})
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_12712\187938647.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Attrition'] = df['Attrition'].replace({'No':0,'Yes':1})

# %%
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
# now we can see that all the values are now numerical

# %%
X = df.drop(['Attrition','Over18'], axis=1)
y = df['Attrition'].values

# %% [markdown]
# # Resampling

# %%
X_over = X
y_over = y

# %%
# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size=0.2, random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\Users\nikhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction=logreg.predict(X_test)
cnf_matrix = confusion_matrix(y_test,prediction)
print("Accuracy Score -", accuracy_score(y_test , prediction))
# Out:
# Accuracy Score - 0.8673469387755102

# %% [markdown]
# # Trying different modles

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier() 
}

# %%
# Train and evaluate each model
model_performance = {}
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    # Make predictions
    y_pred = model.predict(X_test)
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    model_performance[model_name] = {
        'Accuracy': accuracy,
        'Classification Report': report
    }

# %%
# Display model performance
for model_name, performance in model_performance.items():
    print(f"Model: {model_name}")
    print(f"Accuracy: {performance['Accuracy']}")
    print("Classification Report:")
    print(pd.DataFrame(performance['Classification Report']).transpose())
    print("\n")
# Out:
# Model: Logistic Regression
# Accuracy: 0.891156462585034
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.905455  0.976471  0.939623  255.000000
# 1              0.684211  0.333333  0.448276   39.000000
# accuracy       0.891156  0.891156  0.891156    0.891156
# macro avg      0.794833  0.654902  0.693949  294.000000
# weighted avg   0.876106  0.891156  0.874444  294.000000
#
#
# Model: Decision Tree
# Accuracy: 0.7687074829931972
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.875502  0.854902  0.865079  255.000000
# 1              0.177778  0.205128  0.190476   39.000000
# accuracy       0.768707  0.768707  0.768707    0.768707
# macro avg      0.526640  0.530015  0.527778  294.000000
# weighted avg   0.782947  0.768707  0.775591  294.000000
#
#
# Model: Random Forest
# Accuracy: 0.8707482993197279
# Classification Report:
# ...

# %%
# here we see that the logistic regression works much better than other models but still not enough accuracy as the random forest
# in the other models we have trained

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
feature_importances = rf_model.feature_importances_
features = X.columns
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
plt.figure(figsize=(15, 10))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importances')
plt.show()
